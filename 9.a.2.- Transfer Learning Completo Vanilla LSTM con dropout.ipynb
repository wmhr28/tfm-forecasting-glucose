# %%
import codigo
from codigo import utils
from codigo import model_LSTM
from codigo import model_utils
from cg_ega.cg_ega import CG_EGA

# %%
import pandas as pd
import numpy as np
pd.set_option('mode.chained_assignment',None)
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras

# %%
modeloBasePath='modelos/modeloGeneral/vanilla_dropout.h5'
modeloSave='/transfer_vanilla_dropout.h5'

# %%
balanceo='_down_equals'

# %%
from pickle import load
scalerGlucosa = load(open('dataset/generado/scalerGlucosa.scaler', 'rb'))

# %% [markdown]
# # Paciente Q1

# %%
paciente='paciente1'

# %%
with open('dataset/generado/'+paciente+'/array_Xtrain'+balanceo+'.npy', 'rb') as f:
    array_Xtrain = np.load(f)

# %%
len(array_Xtrain)
# Out:
# 237

# %%
with open('dataset/generado/'+paciente+'/array_Ytrain'+balanceo+'.npy', 'rb') as f:
    array_Ytrain = np.load(f)

# %%
len(array_Ytrain)
# Out:
# 237

# %%
with open('dataset/generado/'+paciente+'/array_Xval'+balanceo+'.npy', 'rb') as f:
    array_Xval = np.load(f)

# %%
len(array_Xval)
# Out:
# 51

# %%
with open('dataset/generado/'+paciente+'/array_Yval'+balanceo+'.npy', 'rb') as f:
    array_Yval = np.load(f)

# %%
len(array_Yval)
# Out:
# 51

# %%
with open('dataset/generado/'+paciente+'/array_Xtest.npy', 'rb') as f:
    array_Xtest = np.load(f)

# %%
len(array_Xtest)
# Out:
# 191

# %%
with open('dataset/generado/'+paciente+'/array_Ytest.npy', 'rb') as f:
    array_Ytest = np.load(f)

# %%
len(array_Ytest)
# Out:
# 191

# %%
epochs = 100
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_mae', mode='min', patience=3, min_delta=0.001)

# %% [markdown]
# # Rendimiento del Modelo base

# %%
base_model = keras.models.load_model(modeloBasePath)

# %%
yhat = base_model.predict(array_Xtest)
model_utils.plotPredicted(yhat,array_Ytest)
# Out:
# 6/6 [==============================] - 1s 9ms/step

# %%
model_utils.forecast_accuracy(yhat,array_Ytest)
# Out:
# {'mae': 0.03631403151294948,
#  'mse': 0.05150329549445391,
#  'rmse': 0.0026525894467890367}

# %% [markdown]
# # Iniciamos transfer learning

# %%
base_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                4864
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 9,089
# Trainable params: 9,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
base_model.layers[-2].output
# Out:
# <KerasTensor: shape=(None, 32) dtype=float32 (created by layer 'dropout_2')>

# %%
transferModel=model_LSTM.transferLearning_NewModel(base_model,-2,True)
transferModel.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 30, 5)]           0
#
#  lstm (LSTM)                 (None, 32)                4864
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  newLayer (Dense)            (None, 32)                1056
#
#  newDropout (Dropout)        (None, 32)                0
#
#  newOutput (Dense)           (None, 1)                 33
#
# =================================================================
# Total params: 10,145
# Trainable params: 1,089
# Non-trainable params: 9,056
# _________________________________________________________________

# %%
array_Xtrain.shape
# Out:
# (237, 30, 5)

# %%
transferModel.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001), loss='mse', metrics=['mae','mse'])

history =transferModel.fit(array_Xtrain, array_Ytrain,epochs=epochs, validation_data=(array_Xval, array_Yval), shuffle=False, callbacks=[early_stopping])
transferModel.save('modelos/'+paciente+modeloSave)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 4s 106ms/step - loss: 0.0596 - mae: 0.1817 - mse: 0.0596 - val_loss: 0.0531 - val_mae: 0.1807 - val_mse: 0.0531
# Epoch 2/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0521 - mae: 0.1804 - mse: 0.0521 - val_loss: 0.0509 - val_mae: 0.1777 - val_mse: 0.0509
# Epoch 3/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0532 - mae: 0.1759 - mse: 0.0532 - val_loss: 0.0488 - val_mae: 0.1747 - val_mse: 0.0488
# Epoch 4/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0491 - mae: 0.1713 - mse: 0.0491 - val_loss: 0.0468 - val_mae: 0.1717 - val_mse: 0.0468
# Epoch 5/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0466 - mae: 0.1661 - mse: 0.0466 - val_loss: 0.0448 - val_mae: 0.1687 - val_mse: 0.0448
# Epoch 6/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0439 - mae: 0.1647 - mse: 0.0439 - val_loss: 0.0429 - val_mae: 0.1656 - val_mse: 0.0429
# Epoch 7/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0398 - mae: 0.1542 - mse: 0.0398 - val_loss: 0.0411 - val_mae: 0.1626 - val_mse: 0.0411
# Epoch 8/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0404 - mae: 0.1584 - mse: 0.0404 - val_loss: 0.0393 - val_mae: 0.1597 - val_mse: 0.0393
# Epoch 9/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0399 - mae: 0.1544 - mse: 0.0399 - val_loss: 0.0375 - val_mae: 0.1567 - val_mse: 0.0375
# Epoch 10/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0377 - mae: 0.1538 - mse: 0.0377 - val_loss: 0.0358 - val_mae: 0.1535 - val_mse: 0.0358
# Epoch 11/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0347 - mae: 0.1441 - mse: 0.0347 - val_loss: 0.0342 - val_mae: 0.1505 - val_mse: 0.0342
# Epoch 12/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0325 - mae: 0.1425 - mse: 0.0325 - val_loss: 0.0327 - val_mae: 0.1475 - val_mse: 0.0327
# Epoch 13/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0297 - mae: 0.1373 - mse: 0.0297 - val_loss: 0.0312 - val_mae: 0.1446 - val_mse: 0.0312
# Epoch 14/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0273 - mae: 0.1315 - mse: 0.0273 - val_loss: 0.0298 - val_mae: 0.1418 - val_mse: 0.0298
# Epoch 15/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0285 - mae: 0.1319 - mse: 0.0285 - val_loss: 0.0285 - val_mae: 0.1389 - val_mse: 0.0285
# Epoch 16/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0283 - mae: 0.1338 - mse: 0.0283 - val_loss: 0.0271 - val_mae: 0.1358 - val_mse: 0.0271
# Epoch 17/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0248 - mae: 0.1225 - mse: 0.0248 - val_loss: 0.0257 - val_mae: 0.1326 - val_mse: 0.0257
# Epoch 18/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0232 - mae: 0.1223 - mse: 0.0232 - val_loss: 0.0246 - val_mae: 0.1297 - val_mse: 0.0246
# Epoch 19/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0230 - mae: 0.1224 - mse: 0.0230 - val_loss: 0.0233 - val_mae: 0.1265 - val_mse: 0.0233
# Epoch 20/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0219 - mae: 0.1177 - mse: 0.0219 - val_loss: 0.0221 - val_mae: 0.1234 - val_mse: 0.0221
# Epoch 21/100
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0224 - mae: 0.1173 - mse: 0.0224 - val_loss: 0.0210 - val_mae: 0.1205 - val_mse: 0.0210
# Epoch 22/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.0184 - mae: 0.1085 - mse: 0.0184 - val_loss: 0.0199 - val_mae: 0.1177 - val_mse: 0.0199
# Epoch 23/100
# 8/8 [==============================] - 0s 23ms/step - loss: 0.0169 - mae: 0.1047 - mse: 0.0169 - val_loss: 0.0189 - val_mae: 0.1148 - val_mse: 0.0189
# Epoch 24/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.0194 - mae: 0.1079 - mse: 0.0194 - val_loss: 0.0179 - val_mae: 0.1121 - val_mse: 0.0179
# Epoch 25/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0181 - mae: 0.1042 - mse: 0.0181 - val_loss: 0.0170 - val_mae: 0.1094 - val_mse: 0.0170
# Epoch 26/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0190 - mae: 0.1082 - mse: 0.0190 - val_loss: 0.0161 - val_mae: 0.1066 - val_mse: 0.0161
# Epoch 27/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0164 - mae: 0.0985 - mse: 0.0164 - val_loss: 0.0153 - val_mae: 0.1038 - val_mse: 0.0153
# Epoch 28/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0144 - mae: 0.0955 - mse: 0.0144 - val_loss: 0.0146 - val_mae: 0.1013 - val_mse: 0.0146
# Epoch 29/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0178 - mae: 0.1041 - mse: 0.0178 - val_loss: 0.0139 - val_mae: 0.0987 - val_mse: 0.0139
# Epoch 30/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0143 - mae: 0.0958 - mse: 0.0143 - val_loss: 0.0132 - val_mae: 0.0961 - val_mse: 0.0132
# Epoch 31/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0133 - mae: 0.0914 - mse: 0.0133 - val_loss: 0.0126 - val_mae: 0.0938 - val_mse: 0.0126
# Epoch 32/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0129 - mae: 0.0909 - mse: 0.0129 - val_loss: 0.0121 - val_mae: 0.0916 - val_mse: 0.0121
# Epoch 33/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0131 - mae: 0.0894 - mse: 0.0131 - val_loss: 0.0115 - val_mae: 0.0893 - val_mse: 0.0115
# Epoch 34/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0125 - mae: 0.0860 - mse: 0.0125 - val_loss: 0.0110 - val_mae: 0.0872 - val_mse: 0.0110
# Epoch 35/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0117 - mae: 0.0852 - mse: 0.0117 - val_loss: 0.0107 - val_mae: 0.0855 - val_mse: 0.0107
# Epoch 36/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0128 - mae: 0.0874 - mse: 0.0128 - val_loss: 0.0103 - val_mae: 0.0836 - val_mse: 0.0103
# Epoch 37/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0105 - mae: 0.0805 - mse: 0.0105 - val_loss: 0.0100 - val_mae: 0.0821 - val_mse: 0.0100
# Epoch 38/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0119 - mae: 0.0863 - mse: 0.0119 - val_loss: 0.0098 - val_mae: 0.0808 - val_mse: 0.0098
# Epoch 39/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0124 - mae: 0.0849 - mse: 0.0124 - val_loss: 0.0095 - val_mae: 0.0794 - val_mse: 0.0095
# Epoch 40/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0113 - mae: 0.0854 - mse: 0.0113 - val_loss: 0.0091 - val_mae: 0.0774 - val_mse: 0.0091
# Epoch 41/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0100 - mae: 0.0789 - mse: 0.0100 - val_loss: 0.0087 - val_mae: 0.0754 - val_mse: 0.0087
# Epoch 42/100
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0101 - mae: 0.0820 - mse: 0.0101 - val_loss: 0.0084 - val_mae: 0.0734 - val_mse: 0.0084
# Epoch 43/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0089 - mae: 0.0744 - mse: 0.0089 - val_loss: 0.0080 - val_mae: 0.0717 - val_mse: 0.0080
# Epoch 44/100
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0106 - mae: 0.0762 - mse: 0.0106 - val_loss: 0.0079 - val_mae: 0.0705 - val_mse: 0.0079
# Epoch 45/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0093 - mae: 0.0758 - mse: 0.0093 - val_loss: 0.0077 - val_mae: 0.0696 - val_mse: 0.0077
# Epoch 46/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0083 - mae: 0.0725 - mse: 0.0083 - val_loss: 0.0076 - val_mae: 0.0689 - val_mse: 0.0076
# Epoch 47/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0090 - mae: 0.0756 - mse: 0.0090 - val_loss: 0.0074 - val_mae: 0.0680 - val_mse: 0.0074
# Epoch 48/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0106 - mae: 0.0780 - mse: 0.0106 - val_loss: 0.0073 - val_mae: 0.0670 - val_mse: 0.0073
# Epoch 49/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0098 - mae: 0.0739 - mse: 0.0098 - val_loss: 0.0072 - val_mae: 0.0665 - val_mse: 0.0072
# Epoch 50/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0096 - mae: 0.0756 - mse: 0.0096 - val_loss: 0.0071 - val_mae: 0.0656 - val_mse: 0.0071
# Epoch 51/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0087 - mae: 0.0725 - mse: 0.0087 - val_loss: 0.0070 - val_mae: 0.0647 - val_mse: 0.0070
# Epoch 52/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0118 - mae: 0.0777 - mse: 0.0118 - val_loss: 0.0068 - val_mae: 0.0637 - val_mse: 0.0068
# Epoch 53/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0091 - mae: 0.0746 - mse: 0.0091 - val_loss: 0.0066 - val_mae: 0.0624 - val_mse: 0.0066
# Epoch 54/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0111 - mae: 0.0787 - mse: 0.0111 - val_loss: 0.0065 - val_mae: 0.0615 - val_mse: 0.0065
# Epoch 55/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0095 - mae: 0.0758 - mse: 0.0095 - val_loss: 0.0065 - val_mae: 0.0612 - val_mse: 0.0065
# Epoch 56/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0091 - mae: 0.0729 - mse: 0.0091 - val_loss: 0.0064 - val_mae: 0.0606 - val_mse: 0.0064
# Epoch 57/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0101 - mae: 0.0759 - mse: 0.0101 - val_loss: 0.0063 - val_mae: 0.0600 - val_mse: 0.0063
# Epoch 58/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0100 - mae: 0.0765 - mse: 0.0100 - val_loss: 0.0063 - val_mae: 0.0595 - val_mse: 0.0063
# Epoch 59/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0087 - mae: 0.0718 - mse: 0.0087 - val_loss: 0.0062 - val_mae: 0.0590 - val_mse: 0.0062
# Epoch 60/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0091 - mae: 0.0757 - mse: 0.0091 - val_loss: 0.0062 - val_mae: 0.0586 - val_mse: 0.0062
# Epoch 61/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.0096 - mae: 0.0725 - mse: 0.0096 - val_loss: 0.0061 - val_mae: 0.0581 - val_mse: 0.0061
# Epoch 62/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0110 - mae: 0.0751 - mse: 0.0110 - val_loss: 0.0061 - val_mae: 0.0577 - val_mse: 0.0061
# Epoch 63/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0091 - mae: 0.0703 - mse: 0.0091 - val_loss: 0.0061 - val_mae: 0.0575 - val_mse: 0.0061
# Epoch 64/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0100 - mae: 0.0745 - mse: 0.0100 - val_loss: 0.0060 - val_mae: 0.0571 - val_mse: 0.0060
# Epoch 65/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0107 - mae: 0.0745 - mse: 0.0107 - val_loss: 0.0059 - val_mae: 0.0564 - val_mse: 0.0059
# Epoch 66/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0106 - mae: 0.0747 - mse: 0.0106 - val_loss: 0.0058 - val_mae: 0.0554 - val_mse: 0.0058
# Epoch 67/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0092 - mae: 0.0731 - mse: 0.0092 - val_loss: 0.0057 - val_mae: 0.0549 - val_mse: 0.0057
# Epoch 68/100
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0079 - mae: 0.0669 - mse: 0.0079 - val_loss: 0.0056 - val_mae: 0.0541 - val_mse: 0.0056
# Epoch 69/100
# 8/8 [==============================] - 0s 44ms/step - loss: 0.0093 - mae: 0.0678 - mse: 0.0093 - val_loss: 0.0055 - val_mae: 0.0535 - val_mse: 0.0055
# Epoch 70/100
# 8/8 [==============================] - 0s 41ms/step - loss: 0.0068 - mae: 0.0623 - mse: 0.0068 - val_loss: 0.0054 - val_mae: 0.0529 - val_mse: 0.0054
# Epoch 71/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0090 - mae: 0.0689 - mse: 0.0090 - val_loss: 0.0054 - val_mae: 0.0526 - val_mse: 0.0054
# Epoch 72/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0063 - mae: 0.0625 - mse: 0.0063 - val_loss: 0.0054 - val_mae: 0.0525 - val_mse: 0.0054
# Epoch 73/100
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0069 - mae: 0.0625 - mse: 0.0069 - val_loss: 0.0054 - val_mae: 0.0522 - val_mse: 0.0054

# %%
model_utils.modelEvaluateTraining(transferModel,history,array_Xtest, array_Ytest)
# Out:
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0062 - mae: 0.0660 - mse: 0.0062
# test loss, test acc: [0.0061722700484097, 0.06603255867958069, 0.0061722700484097]

# %%
yhat = transferModel.predict(array_Xtest)
model_utils.plotPredicted(yhat,array_Ytest)
# Out:
# 6/6 [==============================] - 0s 8ms/step

# %%
model_utils.forecast_accuracy(yhat,array_Ytest)
# Out:
# {'mae': 0.06603255606517824,
#  'mse': 0.07856379529900312,
#  'rmse': 0.006172269931783664}

# %%
Y_scaled=scalerGlucosa.inverse_transform(array_Ytest)
yhat_scaled=scalerGlucosa.inverse_transform(yhat)

df_glucose = pd.DataFrame(Y_scaled, columns=['Glucose level True']) 
df_glucose['Nivel True'] = df_glucose['Glucose level True'].apply(utils.label_LevelBG) 
df_glucose['Nivel True'].value_counts().plot.pie(title='Distribución de Niveles de Glucosa',y='level_label',legend=False,autopct='%1.1f%%',figsize=(10, 4))
plt.show()

df_glucose['Glucose level Predict']=yhat_scaled
df_glucose['Nivel Predict'] = df_glucose['Glucose level Predict'].apply(utils.label_LevelBG) 

df_glucose['Nivel Predict'].value_counts().plot.pie(title='Distribución de Niveles de Glucosa',y='level_label',legend=False,autopct='%1.1f%%',figsize=(10, 4))
plt.show()

df_glucose.head()
# Out:
#    Glucose level True  Nivel True  Glucose level Predict Nivel Predict
# 0               124.0  euglycemia             130.094391    euglycemia
# 1               111.0  euglycemia             108.773430    euglycemia
# 2               110.0  euglycemia              87.418015    euglycemia
# 3               109.0  euglycemia              91.710571    euglycemia
# 4                97.0  euglycemia              91.523293    euglycemia

# %%
model_utils.plotPredicted(yhat_scaled,Y_scaled)
model_utils.forecast_accuracy(yhat_scaled,Y_scaled)
# Out:
# {'mae': 30.374974675203493,
#  'mse': 36.1393447571167,
#  'rmse': 1306.0522394737384}

# %%
dfPlot=pd.DataFrame()
dfPlot['y_true']=df_glucose['Glucose level True']
dfPlot['y_pred']=df_glucose['Glucose level Predict']
dfPlot.index=pd.date_range("2023-01-01", periods=len(df_glucose['Glucose level True']), freq="15min")
dfPlot
# Out:
#                      y_true      y_pred
# 2023-01-01 00:00:00   124.0  130.094391
# 2023-01-01 00:15:00   111.0  108.773430
# 2023-01-01 00:30:00   110.0   87.418015
# 2023-01-01 00:45:00   109.0   91.710571
# 2023-01-01 01:00:00    97.0   91.523293
# ...                     ...         ...
# 2023-01-02 22:30:00    83.0   72.566917
# 2023-01-02 22:45:00    76.0   72.440269
# 2023-01-02 23:00:00    67.0   69.229141
# 2023-01-02 23:15:00    63.0   67.391907
# 2023-01-02 23:30:00    63.0   67.540649
#
# [191 rows x 2 columns]

# %%
freq = 15
cg_ega = CG_EGA(dfPlot, freq)
print("AP, BE, EP:", cg_ega.reduced())
cg_ega.plot(day=5)
# Out:
# AP, BE, EP: (0.9105263157894737, 0.07894736842105263, 0.010526315789473684)
